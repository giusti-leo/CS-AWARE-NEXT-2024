# %% [markdown]
# # 11. Data Cleaning

# %%
from datetime import datetime
import os
import time
import pandas as pd 
import requests
import urllib3
import json
import sys
import numpy as np

pd.options.display.max_colwidth = 1000
pd.set_option('display.max_columns', None)

# %%
file = r'C:\Users\leona\OneDrive\Desktop\Tesi\Pipeline\Datasets\Pipeline\DataCollection\OTXAlienVault\Domain.csv'

# %%
df = pd.read_csv(file, low_memory = False)
df
# Out:
#       Unnamed: 0  datetime_int  \
# 0              0    1692293883
# 1              1    1691745243
# 2              2    1694887902
# 3              3    1695694634
# 4              4    1695214458
# ...          ...           ...
# 1767        1767    1654802472
# 1768        1768    1665569446
# 1769        1769    1665569446
# 1770        1770    1685216321
# 1771        1771    1694088943
#
#                                                                   hash  \
# 0     0466d098c4beb3177c544801235119985f13eceebaa61405088f6fcd24fd6e96
# 1     93a6da3e99aa31bef56be969ef66df9ae5aa2a3f7c744fa977486d78384c4de9
# 2     3d5aa422a120da634ebad364a3af6cee0be02a23210cec73bf692bbee545d472
# 3     53efa0ea3650452f5808cd2980b3ea7e0e3038ea283905355b406de8db6844de
# 4     659e11b099e01bd11e0e708e2e6cb9faf762eb1efd4b343b48f41a126d618f6a
# ...                                                                ...
# 1767  87b05c7108251ef607d1b9bd1d717824c6a93d608e58d8e9553e403fa81e5ed9
# 1768  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1769  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1770  d6aaa66ca79bc49452a184140f4f08c324f84f38a3087dac3e44b67d426c15a9
# 1771  9ddfefb536babc1938301bde712e14676e3644dfe2344e9dd67063a493a3e907
#
#                      date       detections.avast detections.avg  \
# 0     2023-08-17T17:38:03                    NaN            NaN
# 1     2023-08-11T09:14:03                    NaN            NaN
# 2     2023-09-16T18:11:42                    NaN            NaN
# 3     2023-09-26T02:17:14                    NaN            NaN
# 4     2023-09-20T12:54:18                    NaN            NaN
# ...                   ...                    ...            ...
# 1767  2022-06-09T19:21:12  Win32:PWSX-gen\ [Trj]            NaN
# 1768  2022-10-12T10:10:46                    NaN            NaN
# 1769  2022-10-12T10:10:46                    NaN            NaN
# 1770  2023-05-27T19:38:41                    NaN            NaN
# 1771  2023-09-07T12:15:43                    NaN            NaN
#
#                   detections.clamav  \
# 0      Win.Trojan.Redline-9938775-1
# 1      Win.Trojan.Redline-9938775-1
# 2                               NaN
# 3     Win.Trojan.NanoCore-9852758-0
# 4        Win.Trojan.Agent-6509946-0
# ...                             ...
# 1767                            NaN
# 1768                            NaN
# 1769                            NaN
# 1770                            NaN
# 1771  Win.Malware.Fugrafa-9938779-0
#
#                                 detections.msdefender  \
# 0                                                 NaN
# 1                                                 NaN
# 2      ALF:HeraklezEval:Trojan:MSIL/AgentTesla.AR!rfn
# 3                        Backdoor:MSIL/Nanocore.S!MTB
# 4                                                 NaN
# ...                                               ...
# 1767                                              NaN
# 1768                                              NaN
# 1769                                              NaN
# 1770  ALF:HeraklezEval:HackTool:Win32/DefenderControl
# 1771                                              NaN
#
#                             domain
# 0                     gr.treef.top
# 1                     no.pleaz.top
# 2     thecookieisthere.duckdns.org
# 3            xdanetnow.duckdns.org
# 4         silentlegion.duckdns.org
# ...                            ...
# 1767     presh147osidufhj.ddns.net
# 1768              pkvithtosh17.com
# 1769              pkvithtosh11.com
# 1770                 ekb.tuktuk.ug
# 1771               srk.stracer.top
#
# [1772 rows x 9 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#       datetime_int  \
# 0       1692293883
# 1       1691745243
# 2       1694887902
# 3       1695694634
# 4       1695214458
# ...            ...
# 1767    1654802472
# 1768    1665569446
# 1769    1665569446
# 1770    1685216321
# 1771    1694088943
#
#                                                                   hash  \
# 0     0466d098c4beb3177c544801235119985f13eceebaa61405088f6fcd24fd6e96
# 1     93a6da3e99aa31bef56be969ef66df9ae5aa2a3f7c744fa977486d78384c4de9
# 2     3d5aa422a120da634ebad364a3af6cee0be02a23210cec73bf692bbee545d472
# 3     53efa0ea3650452f5808cd2980b3ea7e0e3038ea283905355b406de8db6844de
# 4     659e11b099e01bd11e0e708e2e6cb9faf762eb1efd4b343b48f41a126d618f6a
# ...                                                                ...
# 1767  87b05c7108251ef607d1b9bd1d717824c6a93d608e58d8e9553e403fa81e5ed9
# 1768  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1769  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1770  d6aaa66ca79bc49452a184140f4f08c324f84f38a3087dac3e44b67d426c15a9
# 1771  9ddfefb536babc1938301bde712e14676e3644dfe2344e9dd67063a493a3e907
#
#                      date       detections.avast detections.avg  \
# 0     2023-08-17T17:38:03                    NaN            NaN
# 1     2023-08-11T09:14:03                    NaN            NaN
# 2     2023-09-16T18:11:42                    NaN            NaN
# 3     2023-09-26T02:17:14                    NaN            NaN
# 4     2023-09-20T12:54:18                    NaN            NaN
# ...                   ...                    ...            ...
# 1767  2022-06-09T19:21:12  Win32:PWSX-gen\ [Trj]            NaN
# 1768  2022-10-12T10:10:46                    NaN            NaN
# 1769  2022-10-12T10:10:46                    NaN            NaN
# 1770  2023-05-27T19:38:41                    NaN            NaN
# 1771  2023-09-07T12:15:43                    NaN            NaN
#
#                   detections.clamav  \
# 0      Win.Trojan.Redline-9938775-1
# 1      Win.Trojan.Redline-9938775-1
# 2                               NaN
# 3     Win.Trojan.NanoCore-9852758-0
# 4        Win.Trojan.Agent-6509946-0
# ...                             ...
# 1767                            NaN
# 1768                            NaN
# 1769                            NaN
# 1770                            NaN
# 1771  Win.Malware.Fugrafa-9938779-0
#
#                                 detections.msdefender  \
# 0                                                 NaN
# 1                                                 NaN
# 2      ALF:HeraklezEval:Trojan:MSIL/AgentTesla.AR!rfn
# 3                        Backdoor:MSIL/Nanocore.S!MTB
# 4                                                 NaN
# ...                                               ...
# 1767                                              NaN
# 1768                                              NaN
# 1769                                              NaN
# 1770  ALF:HeraklezEval:HackTool:Win32/DefenderControl
# 1771                                              NaN
#
#                             domain
# 0                     gr.treef.top
# 1                     no.pleaz.top
# 2     thecookieisthere.duckdns.org
# 3            xdanetnow.duckdns.org
# 4         silentlegion.duckdns.org
# ...                            ...
# 1767     presh147osidufhj.ddns.net
# 1768              pkvithtosh17.com
# 1769              pkvithtosh11.com
# 1770                 ekb.tuktuk.ug
# 1771               srk.stracer.top
#
# [1772 rows x 8 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Datetype conversion

# %%
df = df.drop(['date'], axis=1)
df['date'] = pd.to_datetime(df['datetime_int'], unit='s')
df = df.drop('datetime_int', axis=1)

df
# Out:
#                                                                   hash  \
# 0     0466d098c4beb3177c544801235119985f13eceebaa61405088f6fcd24fd6e96
# 1     93a6da3e99aa31bef56be969ef66df9ae5aa2a3f7c744fa977486d78384c4de9
# 2     3d5aa422a120da634ebad364a3af6cee0be02a23210cec73bf692bbee545d472
# 3     53efa0ea3650452f5808cd2980b3ea7e0e3038ea283905355b406de8db6844de
# 4     659e11b099e01bd11e0e708e2e6cb9faf762eb1efd4b343b48f41a126d618f6a
# ...                                                                ...
# 1767  87b05c7108251ef607d1b9bd1d717824c6a93d608e58d8e9553e403fa81e5ed9
# 1768  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1769  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1770  d6aaa66ca79bc49452a184140f4f08c324f84f38a3087dac3e44b67d426c15a9
# 1771  9ddfefb536babc1938301bde712e14676e3644dfe2344e9dd67063a493a3e907
#
#            detections.avast detections.avg              detections.clamav  \
# 0                       NaN            NaN   Win.Trojan.Redline-9938775-1
# 1                       NaN            NaN   Win.Trojan.Redline-9938775-1
# 2                       NaN            NaN                            NaN
# 3                       NaN            NaN  Win.Trojan.NanoCore-9852758-0
# 4                       NaN            NaN     Win.Trojan.Agent-6509946-0
# ...                     ...            ...                            ...
# 1767  Win32:PWSX-gen\ [Trj]            NaN                            NaN
# 1768                    NaN            NaN                            NaN
# 1769                    NaN            NaN                            NaN
# 1770                    NaN            NaN                            NaN
# 1771                    NaN            NaN  Win.Malware.Fugrafa-9938779-0
#
#                                 detections.msdefender  \
# 0                                                 NaN
# 1                                                 NaN
# 2      ALF:HeraklezEval:Trojan:MSIL/AgentTesla.AR!rfn
# 3                        Backdoor:MSIL/Nanocore.S!MTB
# 4                                                 NaN
# ...                                               ...
# 1767                                              NaN
# 1768                                              NaN
# 1769                                              NaN
# 1770  ALF:HeraklezEval:HackTool:Win32/DefenderControl
# 1771                                              NaN
#
#                             domain                date
# 0                     gr.treef.top 2023-08-17 17:38:03
# 1                     no.pleaz.top 2023-08-11 09:14:03
# 2     thecookieisthere.duckdns.org 2023-09-16 18:11:42
# 3            xdanetnow.duckdns.org 2023-09-26 02:17:14
# 4         silentlegion.duckdns.org 2023-09-20 12:54:18
# ...                            ...                 ...
# 1767     presh147osidufhj.ddns.net 2022-06-09 19:21:12
# 1768              pkvithtosh17.com 2022-10-12 10:10:46
# 1769              pkvithtosh11.com 2022-10-12 10:10:46
# 1770                 ekb.tuktuk.ug 2023-05-27 19:38:41
# 1771               srk.stracer.top 2023-09-07 12:15:43
#
# [1772 rows x 7 columns]

# %% [markdown]
# # Data Deduplication

# %%
def find_duplicates(input_list):
    seen = {}
    duplicates = []
    for item in input_list:
        if item in seen:
            duplicates.append(item)
        else:
            seen[item] = 1
    return duplicates

# %% [markdown]
# ## Field analyzed: 'hash'

# %%
df['hash'].unique()
# Out:
# array(['0466d098c4beb3177c544801235119985f13eceebaa61405088f6fcd24fd6e96',
#        '93a6da3e99aa31bef56be969ef66df9ae5aa2a3f7c744fa977486d78384c4de9',
#        '3d5aa422a120da634ebad364a3af6cee0be02a23210cec73bf692bbee545d472',
#        ...,
#        'a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e',
#        'd6aaa66ca79bc49452a184140f4f08c324f84f38a3087dac3e44b67d426c15a9',
#        '9ddfefb536babc1938301bde712e14676e3644dfe2344e9dd67063a493a3e907'],
#       dtype=object)

# %%
files = df[df['hash'].notna()]
files
# Out:
#                                                                   hash  \
# 0     0466d098c4beb3177c544801235119985f13eceebaa61405088f6fcd24fd6e96
# 1     93a6da3e99aa31bef56be969ef66df9ae5aa2a3f7c744fa977486d78384c4de9
# 2     3d5aa422a120da634ebad364a3af6cee0be02a23210cec73bf692bbee545d472
# 3     53efa0ea3650452f5808cd2980b3ea7e0e3038ea283905355b406de8db6844de
# 4     659e11b099e01bd11e0e708e2e6cb9faf762eb1efd4b343b48f41a126d618f6a
# ...                                                                ...
# 1767  87b05c7108251ef607d1b9bd1d717824c6a93d608e58d8e9553e403fa81e5ed9
# 1768  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1769  a6b33cbfee592d34c4773d04ff1d3a06bc99d192db31bd1074a81ce25bdd049e
# 1770  d6aaa66ca79bc49452a184140f4f08c324f84f38a3087dac3e44b67d426c15a9
# 1771  9ddfefb536babc1938301bde712e14676e3644dfe2344e9dd67063a493a3e907
#
#            detections.avast detections.avg              detections.clamav  \
# 0                       NaN            NaN   Win.Trojan.Redline-9938775-1
# 1                       NaN            NaN   Win.Trojan.Redline-9938775-1
# 2                       NaN            NaN                            NaN
# 3                       NaN            NaN  Win.Trojan.NanoCore-9852758-0
# 4                       NaN            NaN     Win.Trojan.Agent-6509946-0
# ...                     ...            ...                            ...
# 1767  Win32:PWSX-gen\ [Trj]            NaN                            NaN
# 1768                    NaN            NaN                            NaN
# 1769                    NaN            NaN                            NaN
# 1770                    NaN            NaN                            NaN
# 1771                    NaN            NaN  Win.Malware.Fugrafa-9938779-0
#
#                                 detections.msdefender  \
# 0                                                 NaN
# 1                                                 NaN
# 2      ALF:HeraklezEval:Trojan:MSIL/AgentTesla.AR!rfn
# 3                        Backdoor:MSIL/Nanocore.S!MTB
# 4                                                 NaN
# ...                                               ...
# 1767                                              NaN
# 1768                                              NaN
# 1769                                              NaN
# 1770  ALF:HeraklezEval:HackTool:Win32/DefenderControl
# 1771                                              NaN
#
#                             domain                date
# 0                     gr.treef.top 2023-08-17 17:38:03
# 1                     no.pleaz.top 2023-08-11 09:14:03
# 2     thecookieisthere.duckdns.org 2023-09-16 18:11:42
# 3            xdanetnow.duckdns.org 2023-09-26 02:17:14
# 4         silentlegion.duckdns.org 2023-09-20 12:54:18
# ...                            ...                 ...
# 1767     presh147osidufhj.ddns.net 2022-06-09 19:21:12
# 1768              pkvithtosh17.com 2022-10-12 10:10:46
# 1769              pkvithtosh11.com 2022-10-12 10:10:46
# 1770                 ekb.tuktuk.ug 2023-05-27 19:38:41
# 1771               srk.stracer.top 2023-09-07 12:15:43
#
# [1772 rows x 7 columns]

# %%
dup_files = find_duplicates(files.hash)
len(dup_files)
# Out:
# 186

# %% [markdown]
# ## Summary

# %%
d = dup_files[0]

df[df['hash'] == d]
# Out:
#                                                                 hash  \
# 7   b0324ff69557a45edd1ef4a2d4aee501394249f065552182dc61b611c3a3fe89
# 15  b0324ff69557a45edd1ef4a2d4aee501394249f065552182dc61b611c3a3fe89
#
#    detections.avast detections.avg               detections.clamav  \
# 7               NaN            NaN  Win.Malware.Exploitx-9967939-0
# 15              NaN            NaN  Win.Malware.Exploitx-9967939-0
#
#    detections.msdefender          domain                date
# 7                    NaN    gapi-node.io 2023-09-30 01:31:43
# 15                   NaN  booxshistr.xyz 2023-09-30 01:31:43

# %%
# By a first look at the duplicates in the DB, it seems that there are 
# multiple ip addresses related to the same hash with all the other fields in common

# This function will return true if this assumption will be correct

def analyze_duplicates(df, duplicates):
    
    hp = True
    x = []
    
    for i in range(len(duplicates)):
        
        el = duplicates[i]
        
        dataframe = df[df['hash'] == el]
        dataframe.reset_index(drop=True, inplace=True)
                        
        tmp_avast      = str(dataframe.at[0, 'detections.avast'])
        tmp_clamav     = str(dataframe.at[0, 'detections.clamav'])
        tmp_msdefender = str(dataframe.at[0, 'detections.msdefender'])
        tmp_date       = str(dataframe.at[0, 'date'])
                
        for j in range(len(dataframe) - 1):
            
            if(str(dataframe.at[j + 1 , 'date']) != tmp_date ):
                print(f"{dataframe.at[j + 1 , 'date']} and {tmp_date} are different")
                
                hp = False
                
            if(str(dataframe.at[j + 1 , 'detections.msdefender']) != tmp_msdefender ):
                print(f"{dataframe.at[j + 1 , 'detections.msdefender']} and {tmp_msdefender} are different")

                hp = False
                
            if(str(dataframe.at[j + 1 , 'detections.avast']) != tmp_avast ):
                print(f"{dataframe.at[j + 1 , 'detections.avast']} and {tmp_avast} are different")

                hp = False
                
            if(str(dataframe.at[j + 1 , 'detections.clamav']) != tmp_clamav ):
                print(f"{dataframe.at[j + 1 , 'detections.clamav']} and {tmp_clamav} are different")

                hp = False
            
    return hp

# %%
print(f" The previous hypothesys was correct?  {analyze_duplicates(df, dup_files)}")
# Out:
#  The previous hypothesys was correct?  True

# %% [markdown]
# So, talking about the ER representations: both the fields 'domain' and 'hash' are Keys.

# %% [markdown]
# # Data Enrichment

# %% [raw]
# (Probably this could be done at the end of the pipeline?) In this field i will take into account the 3 fields related to detections and i'll predict a new field

# %% [markdown]
# # Save Dataset

# %%
df.to_csv(r'C:\Users\leona\OneDrive\Desktop\Tesi\Pipeline\Datasets\Pipeline\DataCollection_OTXAlienVault\hash_domain.csv')
