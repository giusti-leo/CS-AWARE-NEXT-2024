# %% [markdown]
# # 14. Data Exploration - OTX Alien Vault

# %%
from datetime import datetime
import os
import time
import pandas as pd 
import requests
import urllib3
import json
import sys
import numpy as np

pd.options.display.max_colwidth = 1000
pd.set_option('display.max_columns', None)

# %%
file = r'C:\Users\leona\OneDrive\Desktop\Tesi\Pipeline\Datasets\Pipeline\DataCollection_OTXAlienVault\IpAddresses_Pulses.csv'

# %%
df_files = pd.read_csv(file, low_memory = False)
df_files
# Out:
#       Unnamed: 0                                             sections  \
# 0              0  ['general', 'url_list', 'http_scans', 'screenshot']
# 1              0  ['general', 'url_list', 'http_scans', 'screenshot']
# 2              0  ['general', 'url_list', 'http_scans', 'screenshot']
# 3              0  ['general', 'url_list', 'http_scans', 'screenshot']
# 4              0  ['general', 'url_list', 'http_scans', 'screenshot']
# ...          ...                                                  ...
# 7147           0  ['general', 'url_list', 'http_scans', 'screenshot']
# 7148           0  ['general', 'url_list', 'http_scans', 'screenshot']
# 7149           0  ['general', 'url_list', 'http_scans', 'screenshot']
# 7150           0  ['general', 'url_list', 'http_scans', 'screenshot']
# 7151           1                                                  NaN
#
#                                                       indicator type  \
# ...
