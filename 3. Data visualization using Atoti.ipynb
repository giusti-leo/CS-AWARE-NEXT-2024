# %%
# !pip install atoti
# !pip install pyngrok
# Out:
# Collecting atoti
#   Downloading atoti-0.8.7-py3-none-any.whl (145.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 2.7 MB/s eta 0:00:00
# Collecting atoti-core (from atoti)
#   Downloading atoti_core-0.8.7-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 6.3 MB/s eta 0:00:00
# Collecting atoti-query==0.8.7 (from atoti)
#   Downloading atoti_query-0.8.7-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 6.5 MB/s eta 0:00:00
# Collecting jdk4py<18,>=17.0.9.2 (from atoti)
#   Downloading jdk4py-17.0.9.2-0-py3-none-manylinux1_x86_64.whl (37.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from atoti) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from atoti) (1.5.3)
# Requirement already satisfied: py4j<0.11,>=0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from atoti) (0.10.9.7)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from atoti) (10.0.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from atoti) (1.10.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from atoti) (4.5.0)
# Collecting pyarrow (from atoti)
#   Downloading pyarrow-14.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from atoti-core->atoti) (7.0.0)
# Collecting numpy (from atoti)
#   Downloading numpy-1.26.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 61.6 MB/s eta 0:00:00
# Collecting pydantic (from atoti)
#   Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 35.2 MB/s eta 0:00:00
# Collecting typing-extensions (from atoti)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->atoti) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->atoti) (2023.3.post1)
# Collecting annotated-types>=0.4.0 (from pydantic->atoti)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic->atoti)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->atoti-core->atoti) (3.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->atoti) (1.16.0)
# Installing collected packages: typing-extensions, numpy, jdk4py, annotated-types, pydantic-core, pyarrow, pydantic, atoti-core, atoti-query, atoti
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ibis-framework 6.2.0 requires pyarrow<13,>=2, but you have pyarrow 14.0.2 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed annotated-types-0.6.0 atoti-0.8.7 atoti-core-0.8.7 atoti-query-0.8.7 jdk4py-17.0.9.2 numpy-1.26.2 pyarrow-14.0.2 pydantic-2.5.2 pydantic-core-2.14.5 typing-extensions-4.9.0
# Collecting pyngrok
#   Downloading pyngrok-7.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.0.3

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
p_entries   = '/content/gdrive/MyDrive/ER_Schema/Entries.csv'
p_tags      = '/content/gdrive/MyDrive/ER_Schema/Tags.csv'
p_alias     = '/content/gdrive/MyDrive/ER_Schema/Alias.csv'
p_cities    = '/content/gdrive/MyDrive/ER_Schema/Cities.csv'
p_countries = '/content/gdrive/MyDrive/ER_Schema/Countries.csv'
p_addresses = '/content/gdrive/MyDrive/ER_Schema/IP_Addresses.csv'

# %%
import pandas as pd
import os

# %% [markdown]
# # Create Tables

# %%
import atoti as tt

session = tt.Session()
# Out:
# Welcome to Atoti 0.8.7!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# Atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, you can request a trial license at https://www.atoti.io/evaluation-license-request.
#
# You can hide this message by setting the `ATOTI_HIDE_EULA_MESSAGE` environment variable to True.

# %%
entries_df = pd.read_csv(p_entries)

entries_df['first_seen'] = pd.to_datetime(entries_df['first_seen'], utc=True)
entries_df['last_seen']  = pd.to_datetime(entries_df['last_seen'], utc=True)

entries_df.head()
# Out:
#     ID_ENTRY    source                                                ioc  \
# 0  2711899.0  URL Haus  https://kld.workout.oystergardener.net/editCon...
# 1  2711898.0  URL Haus                http://178.141.204.195:38244/Mozi.m
# 2  2711896.0  URL Haus  http://mail.treeoflifeadventures.com/wp-conten...
# 3  2711895.0  URL Haus  http://galandskiyher2.com/downloads/toolspub3.exe
# 4  2711893.0  URL Haus  http://galandskiyher2.com/downloads/toolspub2.exe
#
#   ioc_type       threat_type       malware               ip  \
# 0      url  payload_delivery   FAKEUPDATES              NaN
# 1      url  payload_delivery          Mozi  178.141.204.195
# 2      url  payload_delivery  Nanocore RAT              NaN
# 3      url  payload_delivery        Stealc              NaN
# 4      url  payload_delivery        Stealc              NaN
#
#                  first_seen                 last_seen   status  \
# 0 2023-09-15 15:11:08+00:00 2023-09-15 15:11:08+00:00  offline
# 1 2023-09-15 15:03:04+00:00 2023-09-15 15:03:04+00:00  offline
# 2 2023-09-15 13:33:07+00:00 2023-09-15 13:56:00+00:00  offline
# 3 2023-09-15 13:18:06+00:00 2023-09-15 14:54:39+00:00   online
# 4 2023-09-15 13:07:06+00:00 2023-09-15 15:10:11+00:00   online
#
#           reporter
# 0    Cryptolaemus1
# 1       Gandylyan1
# 2  James_inthe_box
# 3          vxvault
# 4          vxvault

# %% [markdown]
# ### ENTRIES

# %%
import pandas as pd
import os

# %%
entry_keys = ['ID_ENTRY', 'source']

column_types = {
    'first_seen': tt.type.ZONED_DATE_TIME,
    'last_seen': tt.type.ZONED_DATE_TIME,
}

# Check if the file exists
if not os.path.exists(p_entries):
    print(f"Error: File not found at {p_entries}")
else:
    table_name = "entries"
    entries = session.read_pandas(entries_df, table_name=table_name, keys = entry_keys)

# %%
entries.head(2)
# Out:
#                                                                   ioc  \
# ID_ENTRY  source
# 2711899.0 URL Haus  https://kld.workout.oystergardener.net/editCon...
# 2711896.0 URL Haus  http://mail.treeoflifeadventures.com/wp-conten...
#
#                    ioc_type       threat_type       malware   ip  \
# ID_ENTRY  source
# 2711899.0 URL Haus      url  payload_delivery   FAKEUPDATES  N/A
# 2711896.0 URL Haus      url  payload_delivery  Nanocore RAT  N/A
#
#                                   first_seen                 last_seen  \
# ID_ENTRY  source
# 2711899.0 URL Haus 2023-09-15 15:11:08+00:00 2023-09-15 15:11:08+00:00
# 2711896.0 URL Haus 2023-09-15 13:33:07+00:00 2023-09-15 13:56:00+00:00
#
#                      status         reporter
# ID_ENTRY  source
# 2711899.0 URL Haus  offline    Cryptolaemus1
# 2711896.0 URL Haus  offline  James_inthe_box

# %% [markdown]
# ### TAGS

# %%
tags_df = pd.read_csv(p_tags)
tags_df['index'] = tags_df.index

tags_df.head()
# Out:
#    ID_ENTRY    source         tag  index
# 0   2704827  URL Haus  SocGholish      0
# 1   2704829  URL Haus        Mozi      1
# 2   2704830  URL Haus        Mozi      2
# 3   2704831  URL Haus        Mozi      3
# 4   2704832  URL Haus        Mozi      4

# %%
tag_keys = ['index']

# Check if the file exists
if not os.path.exists(p_tags):
    print(f"Error: File not found at {p_tags}")
else:
    table_name = "tags"
    tags = session.read_pandas(tags_df, table_name=table_name, keys = tag_keys)

# %%
tags.head(2)
# Out:
#        ID_ENTRY    source   tag
# index
# 1       2704829  URL Haus  Mozi
# 3       2704831  URL Haus  Mozi

# %% [markdown]
# ### ALIAS

# %%
alias_keys = ['malware']

# Check if the file exists
if not os.path.exists(p_alias):
    print(f"Error: File not found at {p_alias}")
else:
    alias = session.read_csv(p_alias, keys = alias_keys)

# %%
alias.head(2)
# Out:
#                                  alias
# malware
# DCRat                  DarkCrystal RAT
# NetSupportManager RAT       NetSupport

# %% [markdown]
# ### IP ADDRESSES

# %%
address_keys = ['ip']

# Check if the file exists
if not os.path.exists(p_addresses):
    print(f"Error: File not found at {p_addresses}")
else:
    ip_addresses = session.read_csv(p_addresses, keys = address_keys)

# %%
ip_addresses.head(2)
# Out:
#                 latitude  longitude     city
# ip
# 27.215.210.106   36.0649   120.3804  Qingdao
# 200.81.166.158   -43.249    -65.305   Trelew

# %% [markdown]
# ### CITIES

# %%
city_keys = ['city']

# Check if the file exists
if not os.path.exists(p_cities):
    print(f"Error: File not found at {p_cities}")
else:
    cities = session.read_csv(p_cities, keys = city_keys)

# %%
cities.head(2)
# Out:
#            country
# city
# Kirov           RU
# Korpilahti      FI

# %% [markdown]
# ### COUNTRY

# %%
country_keys = ['country']

# Check if the file exists
if not os.path.exists(p_countries):
    print(f"Error: File not found at {p_countries}")
else:
    countries = session.read_csv(p_countries, keys = country_keys)

# %%
countries.head(2)
# Out:
#                country_name
# country
# RU       Russian Federation
# FI                  Finland

# %% [markdown]
# # Create Structures

# %%
entries.join(alias,  entries['malware'] == alias['malware'] )

# %%
entries.join(ip_addresses,  entries['ip'] == ip_addresses['ip'] )

# %%
ip_addresses.join(cities,   ip_addresses['city'] == cities['city'] )

# %%
cities.join(countries, cities['country'] == countries['country'] )

# %%
entries.join(tags, entries['ID_ENTRY'] == tags['ID_ENTRY'])

# %%
entries.join(tags, entries['source'] == tags['source'])

# %%
cube = session.create_cube(entries)

# %%
cube.create_date_hierarchy(
    "Date_first_seen",
    column=entries["first_seen"],
    levels={"Year": "yyyy", "Quarter": "QQQ", "Month": "MMM", "Day": "dd"},
)

# %%
cube.create_date_hierarchy(
    "Date_last_seen",
    column=entries["last_seen"],
    levels={"Year": "yyyy", "Quarter": "QQQ", "Month": "MMM", "Day": "dd"},
)

# %%
h, l, m = cube.hierarchies, cube.levels, cube.measures

# %%
cube.schema

# %%
h
# Out:
# {('entries', 'last_seen'): <atoti.hierarchy.Hierarchy object at 0x7b6100262e90>, ('Ip_addresses', 'city'): <atoti.hierarchy.Hierarchy object at 0x7b6100262ef0>, ('tags', 'source'): <atoti.hierarchy.Hierarchy object at 0x7b6100262fe0>, ('entries', 'Date_last_seen'): <atoti.hierarchy.Hierarchy object at 0x7b61002630d0>, ('entries', 'source'): <atoti.hierarchy.Hierarchy object at 0x7b61002631c0>, ('entries', 'ioc'): <atoti.hierarchy.Hierarchy object at 0x7b61002634f0>, ('entries', 'Date_first_seen'): <atoti.hierarchy.Hierarchy object at 0x7b61002635e0>, ('Cities', 'country'): <atoti.hierarchy.Hierarchy object at 0x7b61002636d0>, ('entries', 'ip'): <atoti.hierarchy.Hierarchy object at 0x7b6100263a00>, ('entries', 'reporter'): <atoti.hierarchy.Hierarchy object at 0x7b6100263af0>, ('entries', 'ioc_type'): <atoti.hierarchy.Hierarchy object at 0x7b6100263be0>, ('entries', 'status'): <atoti.hierarchy.Hierarchy object at 0x7b6100263cd0>, ('Alias', 'alias'): <atoti.hierarchy.Hierarchy object at 0x7b6100263dc0>, ('tags', 'index'): <atoti.hierarchy.Hierarchy object at 0x7b6100263eb0>, ('entries', 'ID_ENTRY'): <atoti.hierarchy.Hierarchy object at 0x7b6100263fa0>, ('Countries', 'country_name'): <atoti.hierarchy.Hierarchy object at 0x7b6100262ec0>, ('tags', 'tag'): <atoti.hierarchy.Hierarchy object at 0x7b61002701c0>, ('entries', 'malware'): <atoti.hierarchy.Hierarchy object at 0x7b61002702b0>, ('entries', 'threat_type'): <atoti.hierarchy.Hierarchy object at 0x7b61002703a0>, ('entries', 'first_seen'): <atoti.hierarchy.Hierarchy object at 0x7b6100270490>}

# %%
l
# Out:
# <ul>
# <li>Levels
#   <ul>
#   <li>Day (entries/Date_first_seen/Day)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_first_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Day (entries/Date_last_seen/Day)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_last_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>ID_ENTRY (entries/ID_ENTRY/ID_ENTRY)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: ID_ENTRY</li>
#     <li>type: double</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Month (entries/Date_first_seen/Month)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_first_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Month (entries/Date_last_seen/Month)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_last_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Quarter (entries/Date_first_seen/Quarter)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_first_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Quarter (entries/Date_last_seen/Quarter)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_last_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Year (entries/Date_first_seen/Year)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_first_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>Year (entries/Date_last_seen/Year)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: Date_last_seen</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>alias (Alias/alias/alias)
#     <ul>
#     <li>dimension: Alias</li>
#     <li>hierarchy: alias</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>city (Ip_addresses/city/city)
#     <ul>
#     <li>dimension: Ip_addresses</li>
#     <li>hierarchy: city</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>country (Cities/country/country)
#     <ul>
#     <li>dimension: Cities</li>
#     <li>hierarchy: country</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>country_name (Countries/country_name/country_name)
#     <ul>
#     <li>dimension: Countries</li>
#     <li>hierarchy: country_name</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>first_seen (entries/first_seen/first_seen)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: first_seen</li>
#     <li>type: ZonedDateTime</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>index (tags/index/index)
#     <ul>
#     <li>dimension: tags</li>
#     <li>hierarchy: index</li>
#     <li>type: long</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>ioc (entries/ioc/ioc)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: ioc</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>ioc_type (entries/ioc_type/ioc_type)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: ioc_type</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>ip (entries/ip/ip)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: ip</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>last_seen (entries/last_seen/last_seen)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: last_seen</li>
#     <li>type: ZonedDateTime</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>malware (entries/malware/malware)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: malware</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>reporter (entries/reporter/reporter)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: reporter</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>source (entries/source/source)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: source</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>source (tags/source/source)
#     <ul>
#     <li>dimension: tags</li>
#     <li>hierarchy: source</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>status (entries/status/status)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: status</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>tag (tags/tag/tag)
#     <ul>
#     <li>dimension: tags</li>
#     <li>hierarchy: tag</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   <li>threat_type (entries/threat_type/threat_type)
#     <ul>
#     <li>dimension: entries</li>
#     <li>hierarchy: threat_type</li>
#     <li>type: String</li>
#     <li>order: NaturalOrder</li>
#     </ul>
#   </li>
#   </ul>
# </li>
# </ul>

# %%
m
# Out:
# {'contributors.COUNT': <atoti.measure.Measure object at 0x7b6100262da0>, 'update.TIMESTAMP': <atoti.measure.Measure object at 0x7b61002607f0>}

# %% [markdown]
# # Queries

# %% [markdown]
# ### Most Entries per Day

# %%
_df1 = cube.query(m["contributors.COUNT"], levels=[l[('entries', 'Date_first_seen', 'Day')]])

_df1
# Out:
#                        contributors.COUNT
# Year Quarter Month Day
# 2023 Q3      Aug   16                 162
#                    17                 124
#                    18                  71
#                    19                  98
#                    20                 170
#                    21                 142
#                    22                 168
#                    23                 198
#                    24                 237
#                    25                 343
#                    26                 196
#                    27                 160
#                    28                 180
#                    29                 147
#                    30                 211
#                    31                 160
#              Sep   01                 135
#                    02                 172
#                    03                 150
#                    04                 327
#                    05                 123
#                    06                 146
#                    07                 196
#                    08                 254
#                    09                 328
#                    10               6,729
#                    11                 458
#                    12                 454
#                    13                 354
#                    14                 298
#                    15                 173

# %%
from matplotlib import pyplot as plt
_df1['contributors.COUNT'].plot(kind='line', figsize=(16, 8), title='Entries per day')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### Most Mentioned Tag

# %%
cube.query(m["contributors.COUNT"], levels=[ l['entries', 'source', 'source'], l['tag']])
# Out:
#                            contributors.COUNT
# source     tag
# Threat Fox  BRA                            84
#             Bitter                          2
#             Brute Ratel C4                  2
#             CONTABO                         1
#             Cerberus                        1
# ...                                       ...
# URL Haus   xlam                             1
#            xlsx                             1
#            xmrig                            5
#            xworm                            7
#            zip                             13
#
# [413 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['contributors.COUNT'].plot(kind='hist', bins=20, title='contributors.COUNT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['contributors.COUNT'].plot(kind='line', figsize=(8, 4), title='contributors.COUNT')
# plt.gca().spines[['top', 'right']].set_visible(False)
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['source', 'tag'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['contributors.COUNT'].plot(kind='hist', bins=20, title='contributors.COUNT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['contributors.COUNT'].plot(kind='line', figsize=(8, 4), title='contributors.COUNT')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### Most Mentioned Malware

# %%
from datetime import date

# %%
from_date = date(2023, 9, 1)
to_date   = date(2023, 9, 5)

# %%
mentioned_malwares = cube.query(m["contributors.COUNT"], levels=[l["malware"], l[('entries', 'Date_first_seen', 'Day')]])
mentioned_malwares
# Out:
#                                           contributors.COUNT
# malware            Year Quarter Month Day
# Agent Tesla        2023 Q3      Aug   16                   1
#                                       17                   6
#                                       18                   4
#                                       20                   1
#                                       21                   1
# ...                                                      ...
# Vjw0rm             2023 Q3      Sep   12                   1
#                                       13                   1
# WhiteSnake Stealer 2023 Q3      Sep   09                  32
# XWorm              2023 Q3      Sep   09                   1
#                                       10                 290
#
# [498 rows x 1 columns]

# %%
mm_df = pd.DataFrame(mentioned_malwares).reset_index()

month_mapping = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4,
                 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8,
                 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# Convert 'Month' column to numerical representation
mm_df['M'] = mm_df['Month'].map(month_mapping)
mm_df
# Out:
#                 malware  Year Quarter Month Day  contributors.COUNT  M
# 0           Agent Tesla  2023      Q3   Aug  16                   1  8
# 1           Agent Tesla  2023      Q3   Aug  17                   6  8
# 2           Agent Tesla  2023      Q3   Aug  18                   4  8
# 3           Agent Tesla  2023      Q3   Aug  20                   1  8
# 4           Agent Tesla  2023      Q3   Aug  21                   1  8
# ..                  ...   ...     ...   ...  ..                 ... ..
# 493              Vjw0rm  2023      Q3   Sep  12                   1  9
# 494              Vjw0rm  2023      Q3   Sep  13                   1  9
# 495  WhiteSnake Stealer  2023      Q3   Sep  09                  32  9
# 496               XWorm  2023      Q3   Sep  09                   1  9
# 497               XWorm  2023      Q3   Sep  10                 290  9
#
# [498 rows x 7 columns]

# %%
def create_periodic_summary(df, from_date, to_date):

  dataframe = pd.DataFrame()

  for i in range(len(df)):

    year   =  int(df.loc[i]['Year'])
    month  =  df.loc[i]['M']
    day    =  int(df.loc[i]['Day'])

    if( ( year >= int(from_date.year) ) & ( month >= int(from_date.month) ) & ( day >= int(from_date.day) ) & ( int(to_date.year) >= year ) & ( int(to_date.month) >= month ) & ( int(to_date.day) >= day)):

      #print(f'{year}-{month}-{day}')

      malware = df.at[i,'malware']
      counts = df.at[i,'contributors.COUNT']

      data = {
          'malware' : malware,
          '#times' : counts
      }

      row = pd.DataFrame([data])
      dataframe = pd.concat([dataframe, row], ignore_index=True)
  aggregated_df = dataframe.groupby('malware').sum().reset_index()

  return aggregated_df

# %%
summary = create_periodic_summary(mm_df, from_date, to_date )
summary
# Out:
#                   malware  #times
# 0             Agent Tesla      18
# 1                  Amadey      12
# 2                AsyncRAT      83
# 3             FAKEUPDATES      10
# 4              GootLoader      16
# 5                 Houdini       1
# 6                   IRATA       3
# 7           Lumma Stealer       1
# 8            Mars Stealer       4
# 9             Meterpreter       1
# 10                  Mirai     552
# 11                   Mozi     117
# 12  NetSupportManager RAT       7
# 13                  NjRAT      17
# 14          RecordBreaker      14
# 15        RedLine Stealer      27
# 16                 Remcos      10
# 17            SmokeLoader       4
# 18                 Stealc       8
# 19                  Vidar       2

# %%
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap

cmap = get_cmap('tab10')
colors = cmap(range(len(summary)))

plt.pie(summary['#times'])

plt.legend(summary['malware'], title='Malwares', loc='upper right', bbox_to_anchor=(2, 0.9))

# Add a title
plt.title(f'Malwares entries between {from_date} and {to_date}')

# Muestra el gráfico
plt.show()
# Out:
# <ipython-input-253-621d38c9264f>:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')

# %%
'''
d = date(2023, 9, 11)

filter_condition = (
    (l[('entries', 'Date_first_seen', 'Day')] == d.day)
    & (l[('entries', 'Date_first_seen', 'Month')] == d.month)
    & (l[('entries', 'Date_first_seen', 'Year')] == d.year)
)

m["Entries.period"] = tt.filter(
    m["contributors.COUNT"], filter_condition
)

# Perform the query with the updated filter condition

result = cube.query(
    m["Entries.period"],
)

result
'''
# Out:
# '\nd = date(2023, 9, 11)\n\nfilter_condition = (\n    (l[(\'entries\', \'Date_first_seen\', \'Day\')] == d.day)\n    & (l[(\'entries\', \'Date_first_seen\', \'Month\')] == d.month)\n    & (l[(\'entries\', \'Date_first_seen\', \'Year\')] == d.year)\n)\n\nm["Entries.period"] = tt.filter(\n    m["contributors.COUNT"], filter_condition\n)\n\n# Perform the query with the updated filter condition\n\nresult = cube.query(\n    m["Entries.period"],\n)\n\nresult\n'

# %% [markdown]
# ### Most Active Reporter

# %%
cube.query(m["contributors.COUNT"], levels=[ l['entries', 'source', 'source'], l['reporter']])
# Out:
#                            contributors.COUNT
# source     reporter
# Threat Fox 0xrb                             1
#            1ZRR4H                         118
#            500mk500                       167
#            Gi7w0rm                      6,496
#            Gootloader2                      8
#            Hato0                            8
#            Rony                            12
#            SarlackLab                      15
#            abus3reports                     1
#            abuse_ch                       212
#            anonymous                        6
#            cre4milk                         3
#            crep1x                          23
#            drb_ra                         614
#            g0njxa                          33
#            malpulse                       234
#            monitorsg                        2
#            myonium1                        12
#            sicehicetf                       1
#            stoerchl                         1
#            teamcymru_S2                     1
#            vovaan                           6
# URL Haus   AndreGironda                     2
#            Casperinous                     53
#            Ch3tank                          1
#            Cryptolaemus1                   76
#            ErikGottko                       2
#            Gandylyan1                     360
#            Gootloader2                    269
#            JAMESWT_MHT                     53
#            James_inthe_box                 23
#            Manu3l_Varela                    3
#            OneCert                          3
#            SquiblydooBlog                   1
#            THProfiler                       1
#            TomU                             3
#            ULTRAFRAUD                       8
#            UkyKnight                        1
#            abus3reports                   211
#            abuse_ch                       440
#            andretavare5                   108
#            anonymous                       44
#            dms1899                          4
#            ffforward                       19
#            furry3000                        2
#            geenensp                       352
#            lrz_urlhaus                    464
#            onecert_ir                       8
#            pmelson                        136
#            tammeto                         22
#            tolisec                      1,841
#            vmovupd                          2
#            vovaan                          13
#            vxvault                          8
#            zbetcheckin                    557

# %% [markdown]
# ### Entries for each Country

# %%
cube.query(m["contributors.COUNT"], levels=[l['country_name']],)
# Out:
#                                                   contributors.COUNT
# country_name
# Albania                                                            5
# Algeria                                                            1
# Antarctica                                                         1
# Argentina                                                        131
# Australia                                                         25
# ...                                                              ...
# United Kingdom of Great Britain and Northern I...                157
# United States of America                                       1,024
# Venezuela (Bolivarian Republic of)                                 4
# Vietnam                                                          206
# Virgin Islands (British)                                           1
#
# [92 rows x 1 columns]

# %% [markdown]
# ### Most Active Malware by day

# %%
cube.query(m["contributors.COUNT"], levels=[l['malware'], l['Day'],])
# Out:
#                                           contributors.COUNT
# malware            Year Quarter Month Day
# Agent Tesla        2023 Q3      Aug   16                   1
#                                       17                   6
#                                       18                   4
#                                       20                   1
#                                       21                   1
# ...                                                      ...
# Vjw0rm             2023 Q3      Sep   12                   1
#                                       13                   1
# WhiteSnake Stealer 2023 Q3      Sep   09                  32
# XWorm              2023 Q3      Sep   09                   1
#                                       10                 290
#
# [498 rows x 1 columns]

# %% [markdown]
# ### Most Active Malware by location

# %%
res = cube.query(m["contributors.COUNT"], levels=[l['city'],l['malware']])
dataframe_most_active_malware = pd.DataFrame(res)
dataframe_most_active_malware = dataframe_most_active_malware.reset_index()
dataframe_most_active_malware
# Out:
#                  city        malware  contributors.COUNT
# 0     Aalsmeerderbrug       AsyncRAT                   6
# 1     Aalsmeerderbrug     Quasar RAT                   1
# 2     Aalsmeerderbrug          XWorm                   1
# 3             Abbenes       AsyncRAT                   1
# 4             Abbenes         Remcos                   2
# ...               ...            ...                 ...
# 1179               Ōi  Cobalt Strike                   2
# 1180               Ōi     Quasar RAT                   2
# 1181               Ōi         Remcos                   2
# 1182            Şişli       AsyncRAT                   2
# 1183            Şişli  Cobalt Strike                   2
#
# [1184 rows x 3 columns]

# %%
dataframe_ip_addresses = pd.read_csv(p_addresses)
dataframe_ip_addresses = dataframe_ip_addresses[['latitude', 'longitude',	'city']].drop_duplicates().sort_values(by = 'city')
dataframe_ip_addresses = dataframe_ip_addresses
dataframe_ip_addresses
# Out:
#       latitude  longitude             city
# 5518   52.2795     4.7548  Aalsmeerderbrug
# 5151   52.2609     4.6391          Abbenes
# 5567   32.4487   -99.7331          Abilene
# 6347   24.4512    54.3970        Abu Dhabi
# 1977    9.0579     7.4951            Abuja
# ...        ...        ...              ...
# 5701   38.4127    27.1384            İzmir
# 5741   38.4000    27.1000            İzmir
# 4185   35.6090   139.7302               Ōi
# 5669   41.0483    28.9521            Şişli
# 5668   41.0605    28.9872            Şişli
#
# [614 rows x 3 columns]

# %%
merged_df = pd.merge(dataframe_most_active_malware, dataframe_ip_addresses, on='city')
merged_df
# Out:
#                  city        malware  contributors.COUNT  latitude  longitude
# 0     Aalsmeerderbrug       AsyncRAT                   6   52.2795     4.7548
# 1     Aalsmeerderbrug     Quasar RAT                   1   52.2795     4.7548
# 2     Aalsmeerderbrug          XWorm                   1   52.2795     4.7548
# 3             Abbenes       AsyncRAT                   1   52.2609     4.6391
# 4             Abbenes         Remcos                   2   52.2609     4.6391
# ...               ...            ...                 ...       ...        ...
# 1959               Ōi         Remcos                   2   35.6090   139.7302
# 1960            Şişli       AsyncRAT                   2   41.0483    28.9521
# 1961            Şişli       AsyncRAT                   2   41.0605    28.9872
# 1962            Şişli  Cobalt Strike                   2   41.0483    28.9521
# 1963            Şişli  Cobalt Strike                   2   41.0605    28.9872
#
# [1964 rows x 5 columns]

# %%
# !pip install folium plotly geopandas basemap bokeh
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Collecting basemap
#   Downloading basemap-1.3.8-cp310-cp310-manylinux1_x86_64.whl (860 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.7/860.7 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.5)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.2)
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: pyshp<2.4,>=1.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.8,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Collecting numpy (from folium)
#   Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2023.10.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (67.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Installing collected packages: numpy, basemap-data, basemap
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2
#     Uninstalling numpy-1.26.2:
#       Successfully uninstalled numpy-1.26.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ibis-framework 6.2.0 requires pyarrow<13,>=2, but you have pyarrow 14.0.2 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed basemap-1.3.8 basemap-data-1.3.2 numpy-1.25.2

# %% [markdown]
# ### **Fopium**

# %%
import folium

mymap = folium.Map(location=[45.5236, -122.6750], zoom_start=13)

folium.Marker(
    location=[45.5236, -122.6750],
    popup="Hello, this is a marker!",
).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11c08ce6e79b41db2eb898bc4a62debc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11c08ce6e79b41db2eb898bc4a62debc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11c08ce6e79b41db2eb898bc4a62debc = L.map(
#                 &quot;map_11c08ce6e79b41db2eb898bc4a62debc&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40fba3eb20a866f26d8d1e31e953a7dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11c08ce6e79b41db2eb898bc4a62debc);
#
#
#             var marker_130c83fa11cd4b6fd87e24e42aa677bf = L.marker(
#                 [45.5236, -122.675],
#                 {}
#             ).addTo(map_11c08ce6e79b41db2eb898bc4a62debc);
#
#
#         var popup_94575488b8dc9e85078ca5a342fd2e2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9159566e4548cade0a57664b853f39a = $(`&lt;div id=&quot;html_a9159566e4548cade0a57664b853f39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello, this is a marker!&lt;/div&gt;`)[0];
#                 popup_94575488b8dc9e85078ca5a342fd2e2b.setContent(html_a9159566e4548cade0a57664b853f39a);
#
#
#
#         marker_130c83fa11cd4b6fd87e24e42aa677bf.bindPopup(popup_94575488b8dc9e85078ca5a342fd2e2b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_graph(df):

  df_cities = df[['latitude', 'longitude']].drop_duplicates().reset_index()

  mymap = folium.Map(location=[ 100 , 100], zoom_start= 1)

  for i in range(len(df_cities)):

    longitude =  df.loc[i]['longitude']
    latitude  =  df.loc[i]['latitude']

    malwares = df[ (df['latitude'] == latitude) & (df['longitude'] == longitude) ]
    max_value_index = malwares['contributors.COUNT'].idxmax()

    row_with_max_value = df.loc[max_value_index]

    create_pop_up(row_with_max_value['latitude'], row_with_max_value['longitude'], row_with_max_value['contributors.COUNT'], row_with_max_value['malware'], mymap )

  return mymap

def create_pop_up(latitude, longitude, contributors, malware, mymap):

  folium.Marker(
    location=[latitude, longitude],
    popup=f"{contributors} {malware} entries found",
  ).add_to(mymap)

# %%
create_graph(merged_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa228e8cb8bd23efc3bc8da6fcc70006 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa228e8cb8bd23efc3bc8da6fcc70006&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa228e8cb8bd23efc3bc8da6fcc70006 = L.map(
#                 &quot;map_aa228e8cb8bd23efc3bc8da6fcc70006&quot;,
#                 {
#                     center: [100.0, 100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6694c80af577811be557833ab079283e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#             var marker_8213b64bbf561b46322784a5a3de4ffd = L.marker(
#                 [52.2795, 4.7548],
#                 {}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#         var popup_2ff6483b64bad23c203fecee99210e49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53e6ec86bdd76d18e0499b6df914b070 = $(`&lt;div id=&quot;html_53e6ec86bdd76d18e0499b6df914b070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6 AsyncRAT entries found&lt;/div&gt;`)[0];
#                 popup_2ff6483b64bad23c203fecee99210e49.setContent(html_53e6ec86bdd76d18e0499b6df914b070);
#
#
#
#         marker_8213b64bbf561b46322784a5a3de4ffd.bindPopup(popup_2ff6483b64bad23c203fecee99210e49)
#         ;
#
#
#
#
#             var marker_78fe083d45ba903f6fddbb782566f365 = L.marker(
#                 [52.2795, 4.7548],
#                 {}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#         var popup_057f2594eec0081d607f6ddc5aa1a3c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70af8c9508ea8303e8c00b37d5cf57fa = $(`&lt;div id=&quot;html_70af8c9508ea8303e8c00b37d5cf57fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6 AsyncRAT entries found&lt;/div&gt;`)[0];
#                 popup_057f2594eec0081d607f6ddc5aa1a3c1.setContent(html_70af8c9508ea8303e8c00b37d5cf57fa);
#
#
#
#         marker_78fe083d45ba903f6fddbb782566f365.bindPopup(popup_057f2594eec0081d607f6ddc5aa1a3c1)
#         ;
#
#
#
#
#             var marker_1a7287ef0721a067e159b4f0cd382e1e = L.marker(
#                 [52.2795, 4.7548],
#                 {}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#         var popup_b717fd14a7b80baf475c07269c8f1abf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e04df4fdd18c326cf46232c40483eaad = $(`&lt;div id=&quot;html_e04df4fdd18c326cf46232c40483eaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6 AsyncRAT entries found&lt;/div&gt;`)[0];
#                 popup_b717fd14a7b80baf475c07269c8f1abf.setContent(html_e04df4fdd18c326cf46232c40483eaad);
#
#
#
#         marker_1a7287ef0721a067e159b4f0cd382e1e.bindPopup(popup_b717fd14a7b80baf475c07269c8f1abf)
#         ;
#
#
#
#
#             var marker_5e8913923ecfbd9cc38d8359ff8884de = L.marker(
#                 [52.2609, 4.6391],
#                 {}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#         var popup_3ac9de23594afbcf2f9b044f06a5edbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04a0e8008bdb96ec58738603b63b4a91 = $(`&lt;div id=&quot;html_04a0e8008bdb96ec58738603b63b4a91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 Remcos entries found&lt;/div&gt;`)[0];
#                 popup_3ac9de23594afbcf2f9b044f06a5edbf.setContent(html_04a0e8008bdb96ec58738603b63b4a91);
#
#
#
#         marker_5e8913923ecfbd9cc38d8359ff8884de.bindPopup(popup_3ac9de23594afbcf2f9b044f06a5edbf)
#         ;
#
#
#
#
#             var marker_31ea887d63655d80c748424dc59f77e3 = L.marker(
#                 [52.2609, 4.6391],
#                 {}
#             ).addTo(map_aa228e8cb8bd23efc3bc8da6fcc70006);
#
#
#         var popup_d4a0d8144bf120347629036b14484c69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7e747d3b44eabb2a3f2c1372c1eb7f8 = $(`&lt;div id=&quot;html_a7e747d3b44eabb2a3f2c1372c1eb7f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 Remcos entries found&lt;/div&gt;`)[0];
#                 popup_d4a0d8144bf120347629036b14484c69.setContent(html_a7e747d3b44eabb2a3f2c1372c1eb7f8);
#
#
#
#         marker_31ea887d63655d80c748424dc59f77e3.bindPopup(popup_d4a0d8144bf120347629036b14484c69)
#         ;
#
#
#
#
#             var marker_b66eb9fed7df344b3ae822649bedb1fe = L.marker(
#                 [32.4487, -99.7331],
