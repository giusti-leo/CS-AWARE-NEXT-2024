# %% [markdown]
# ## 1.2. Data Collection source URL Haus

# %%
import csv, urllib.request
import pandas as pd 
import requests

# %%
pd.options.display.max_colwidth = 500
pd.set_option('display.max_columns', None)

# %%
json_URL = 'https://urlhaus.abuse.ch/downloads/csv_recent/'

with requests.Session() as s:
    download = s.get(json_URL)

    df = pd.read_csv(json_URL, header = 8,on_bad_lines='skip')
    
df
# Out:
#          # id            dateadded  \
# 0     2711900  2023-09-15 15:17:09
# 1     2711899  2023-09-15 15:11:08
# 2     2711898  2023-09-15 15:03:04
# 3     2711897  2023-09-15 13:35:07
# 4     2711896  2023-09-15 13:33:07
# ...       ...                  ...
# 7051  2704832  2023-08-16 00:03:35
# 7052  2704830  2023-08-16 00:03:34
# 7053  2704831  2023-08-16 00:03:34
# 7054  2704829  2023-08-16 00:03:06
# 7055  2704827  2023-08-16 00:01:06
#
#                                                                                                                             url  \
# 0                                                                                                    http://1.32.53.97:45188/.i
# 1                                                                            https://kld.workout.oystergardener.net/editContent
# 2                                                                                           http://178.141.204.195:38244/Mozi.m
# ...

# %%
df.columns
# Out:
# Index(['# id', 'dateadded', 'url', 'url_status', 'last_online', 'threat',
#        'tags', 'urlhaus_link', 'reporter'],
#       dtype='object')

# %%
len(df)
# Out:
# 7056

# %%
df.to_csv(r'C:\Users\leona\OneDrive\Desktop\Tesi\Pipeline\Datasets\Pipeline\URL_HAUS.csv')
