# %% [markdown]
# # 16.0. Data Cleaning - OTX Alien Vault

# %%
from datetime import datetime
import os
import time
import pandas as pd
import requests
import urllib3
import json
import sys
import numpy as np

pd.options.display.max_colwidth = 1000
pd.set_option('display.max_columns', None)

# %%
path_OTX_Entries     = r"C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\DataAnalysis\\otx_alien_vault\\Entries.csv"
path_OTX_Anomalies   = r"C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\DataAnalysis\\otx_alien_vault\\Anomalies.csv"
path_OTX_Attacks     = r"C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\DataAnalysis\\otx_alien_vault\\Attacks.csv"
path_OTX_Behaviours  = r"C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\DataAnalysis\\otx_alien_vault\\Behaviours.csv"
path_OTX_TV_Analysis = r"C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\DataAnalysis\\otx_alien_vault\\TV_Analysis.csv"

# %% [markdown]
# # Entries

# %%
entries = pd.read_csv(path_OTX_Entries, low_memory = False)
entries.head(3)
# Out:
#                  analysis.info.results.sha1  \
# 0  b701b181de8e595225668cb65d5b975e5b300a39
# 1  713a00b13a87c52b43404cd32d0f4645844709d9
# 2  e900de5aea86567fadc7507a6811596eb4b86a14
#
#                                        analysis.info.results.sha256  \
# 0  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1  3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2  3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
#
#           analysis.info.results.md5 page_type analysis.datetime_int
# 0  d6cda532ce834b973d5292e05e1d6c38      PEXE   2022-02-25T20:30:34
# 1  97ad0714b0245825407dd25d7d168d31      PEXE   2018-11-21T00:58:28
# 2  e076afd88fe6a708d91a3f771754e860      PEXE   2022-07-07T00:45:04

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Column Renaming

# %%
entries.rename(columns=
               {   'analysis.info.results.sha1'                            : 'sha1', 
                   'analysis.info.results.sha256'                          : 'sha256', 
                   'analysis.info.results.md5'                             : 'md5', 
                   'analysis.datetime_int'                                 : 'analysis_date', 
                   'page_type'                                             : 'file_type'}
          , inplace=True)
entries
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 2653  3ab53037e2360c42b57d213234ced58717844a71
# 2654  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 2655  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 2656  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 2657  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 2653  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 2654  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 2655  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 2656  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 2657  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5 file_type        analysis_date
# 0     d6cda532ce834b973d5292e05e1d6c38      PEXE  2022-02-25T20:30:34
# 1     97ad0714b0245825407dd25d7d168d31      PEXE  2018-11-21T00:58:28
# 2     e076afd88fe6a708d91a3f771754e860      PEXE  2022-07-07T00:45:04
# 3     497d3c4d08b80e03f622064dced10135      PEXE  2021-12-20T02:27:16
# 4     260bf0106c006d4e988a2685df71a758      PEXE  2020-10-09T19:29:05
# ...                                ...       ...                  ...
# 2653  e0fea510c784eb0e440e99e53d83d414      PEXE  2021-07-14T04:25:36
# 2654  c9f771be253b6ca1d7a808d7d65c5e29      PEXE  2020-09-08T06:08:36
# 2655  0550342e66698384f232ac39b700dd14      PEXE  2020-11-21T16:28:28
# 2656  fe783ff4bccd76cb215ee1f7738d9ed5      PEXE  2021-12-20T19:52:42
# 2657  1b47215513edd622ba825dced07c8969      PEXE  2021-11-11T22:17:54
#
# [2658 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Standardization
# - the columns file_format are all converted to lower case

# %%
entries['file_type'] = entries['file_type'].str.lower()

# %%
entries['file_type'] = entries['file_type'].replace('pexe', 'exe', regex=True).str.lower()

entries.file_type.unique()
# Out:
# array(['exe', 'elf', nan, 'sh', 'vbs', 'lnk', 'js', 'ooxml', 'android',
#        'generic', 'ps', 'msi', 'rtf', 'cdf', 'hta', 'bat', 'pdf'],
#       dtype=object)

# %% [markdown]
# #### Data type Conversion

# %% [markdown]
# - analysis_date field : from string to date

# %%
entries['analysis_date'] = pd.to_datetime(entries['analysis_date']).dt.strftime('%Y-%m-%d')
entries
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 2653  3ab53037e2360c42b57d213234ced58717844a71
# 2654  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 2655  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 2656  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 2657  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 2653  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 2654  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 2655  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 2656  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 2657  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5 file_type analysis_date
# 0     d6cda532ce834b973d5292e05e1d6c38       exe    2022-02-25
# 1     97ad0714b0245825407dd25d7d168d31       exe    2018-11-21
# 2     e076afd88fe6a708d91a3f771754e860       exe    2022-07-07
# 3     497d3c4d08b80e03f622064dced10135       exe    2021-12-20
# 4     260bf0106c006d4e988a2685df71a758       exe    2020-10-09
# ...                                ...       ...           ...
# 2653  e0fea510c784eb0e440e99e53d83d414       exe    2021-07-14
# 2654  c9f771be253b6ca1d7a808d7d65c5e29       exe    2020-09-08
# 2655  0550342e66698384f232ac39b700dd14       exe    2020-11-21
# 2656  fe783ff4bccd76cb215ee1f7738d9ed5       exe    2021-12-20
# 2657  1b47215513edd622ba825dced07c8969       exe    2021-11-11
#
# [2658 rows x 5 columns]

# %% [markdown]
# #### Missing Values
#
# - drop rows with missing values related to sha1 sha256, md5 fields because they are the keys of the entity Entries

# %%
entries.dropna(subset=['sha1', 'sha256', 'md5'], inplace=True)
entries.reset_index(drop=True, inplace=True)

entries
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 2641  3ab53037e2360c42b57d213234ced58717844a71
# 2642  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 2643  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 2644  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 2645  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 2641  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 2642  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 2643  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 2644  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 2645  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5 file_type analysis_date
# 0     d6cda532ce834b973d5292e05e1d6c38       exe    2022-02-25
# 1     97ad0714b0245825407dd25d7d168d31       exe    2018-11-21
# 2     e076afd88fe6a708d91a3f771754e860       exe    2022-07-07
# 3     497d3c4d08b80e03f622064dced10135       exe    2021-12-20
# 4     260bf0106c006d4e988a2685df71a758       exe    2020-10-09
# ...                                ...       ...           ...
# 2641  e0fea510c784eb0e440e99e53d83d414       exe    2021-07-14
# 2642  c9f771be253b6ca1d7a808d7d65c5e29       exe    2020-09-08
# 2643  0550342e66698384f232ac39b700dd14       exe    2020-11-21
# 2644  fe783ff4bccd76cb215ee1f7738d9ed5       exe    2021-12-20
# 2645  1b47215513edd622ba825dced07c8969       exe    2021-11-11
#
# [2646 rows x 5 columns]

# %%
completeness = 1 - entries['sha1'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'sha1': {completeness * 100:.2f}%")

completeness = 1 - entries['sha256'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'sha256': {completeness * 100:.2f}%")

completeness = 1 - entries['md5'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'md5': {completeness * 100:.2f}%")

completeness = 1 - entries['analysis_date'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'analysis_date': {completeness * 100:.2f}%")

completeness = 1 - entries['file_type'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'file_type': {completeness * 100:.2f}%")
# Out:
# Completeness for 'sha1': 100.00%
# Completeness for 'sha256': 100.00%
# Completeness for 'md5': 100.00%
# Completeness for 'analysis_date': 100.00%
# Completeness for 'file_type': 100.00%

# %% [markdown]
# # Anomalies

# %%
anomalies = pd.read_csv(path_OTX_Anomalies, low_memory = False)
anomalies.head(3)
# Out:
#                    name                                      sha1  \
# 0  checksum_header_zero  b701b181de8e595225668cb65d5b975e5b300a39
# 1  checksum_header_zero  e900de5aea86567fadc7507a6811596eb4b86a14
# 2         entropy_based  12d263832d7f08122fbfc4431da22016e0823539
#
#                                                              sha256  \
# 0  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1  3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 2  cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
#
#                                 md5
# 0  d6cda532ce834b973d5292e05e1d6c38
# 1  e076afd88fe6a708d91a3f771754e860
# 2  497d3c4d08b80e03f622064dced10135

# %%
print("Any NaN values in the DataFrame:", anomalies.isna().any().any())
# Out:
# Any NaN values in the DataFrame: False

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Column Renaming

# %%
anomalies.rename(columns= { 'name' : 'anomaly_name' }, inplace=True)
anomalies
# Out:
#               anomaly_name                                      sha1  \
# 0     checksum_header_zero  b701b181de8e595225668cb65d5b975e5b300a39
# 1     checksum_header_zero  e900de5aea86567fadc7507a6811596eb4b86a14
# 2            entropy_based  12d263832d7f08122fbfc4431da22016e0823539
# 3     checksum_header_zero  12d263832d7f08122fbfc4431da22016e0823539
# 4     checksum_header_zero  18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                    ...                                       ...
# 3233         entropy_based  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3234  checksum_header_zero  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3235  checksum_header_zero  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 3236  checksum_header_zero  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 3237  checksum_header_zero  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 2     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 3233  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3234  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3235  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 3236  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 3237  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5
# 0     d6cda532ce834b973d5292e05e1d6c38
# 1     e076afd88fe6a708d91a3f771754e860
# 2     497d3c4d08b80e03f622064dced10135
# 3     497d3c4d08b80e03f622064dced10135
# 4     260bf0106c006d4e988a2685df71a758
# ...                                ...
# 3233  c9f771be253b6ca1d7a808d7d65c5e29
# 3234  c9f771be253b6ca1d7a808d7d65c5e29
# 3235  0550342e66698384f232ac39b700dd14
# 3236  fe783ff4bccd76cb215ee1f7738d9ed5
# 3237  1b47215513edd622ba825dced07c8969
#
# [3238 rows x 4 columns]

# %%
anomaly_columns = ['sha1', 'sha256', 'md5', 'anomaly_name']
anomalies = anomalies[anomaly_columns]
anomalies
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     e900de5aea86567fadc7507a6811596eb4b86a14
# 2     12d263832d7f08122fbfc4431da22016e0823539
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 3233  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3234  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3235  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 3236  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 3237  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 2     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 3233  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3234  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3235  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 3236  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 3237  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5          anomaly_name
# 0     d6cda532ce834b973d5292e05e1d6c38  checksum_header_zero
# 1     e076afd88fe6a708d91a3f771754e860  checksum_header_zero
# 2     497d3c4d08b80e03f622064dced10135         entropy_based
# 3     497d3c4d08b80e03f622064dced10135  checksum_header_zero
# 4     260bf0106c006d4e988a2685df71a758  checksum_header_zero
# ...                                ...                   ...
# 3233  c9f771be253b6ca1d7a808d7d65c5e29         entropy_based
# 3234  c9f771be253b6ca1d7a808d7d65c5e29  checksum_header_zero
# 3235  0550342e66698384f232ac39b700dd14  checksum_header_zero
# 3236  fe783ff4bccd76cb215ee1f7738d9ed5  checksum_header_zero
# 3237  1b47215513edd622ba825dced07c8969  checksum_header_zero
#
# [3238 rows x 4 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Missing Values
#
# - drop rows with missing values related to sha1 sha256, md5 and anomaly_name field because they are the keys of that row

# %%
anomalies.dropna(subset=['sha1', 'sha256', 'md5', 'anomaly_name'], inplace=True)
anomalies.reset_index(drop=True, inplace=True)

anomalies
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     e900de5aea86567fadc7507a6811596eb4b86a14
# 2     12d263832d7f08122fbfc4431da22016e0823539
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 3233  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3234  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3235  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 3236  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 3237  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 2     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 3233  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3234  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3235  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 3236  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 3237  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5          anomaly_name
# 0     d6cda532ce834b973d5292e05e1d6c38  checksum_header_zero
# 1     e076afd88fe6a708d91a3f771754e860  checksum_header_zero
# 2     497d3c4d08b80e03f622064dced10135         entropy_based
# 3     497d3c4d08b80e03f622064dced10135  checksum_header_zero
# 4     260bf0106c006d4e988a2685df71a758  checksum_header_zero
# ...                                ...                   ...
# 3233  c9f771be253b6ca1d7a808d7d65c5e29         entropy_based
# 3234  c9f771be253b6ca1d7a808d7d65c5e29  checksum_header_zero
# 3235  0550342e66698384f232ac39b700dd14  checksum_header_zero
# 3236  fe783ff4bccd76cb215ee1f7738d9ed5  checksum_header_zero
# 3237  1b47215513edd622ba825dced07c8969  checksum_header_zero
#
# [3238 rows x 4 columns]

# %% [markdown]
# #### Standardization
# - the columns yara_rule_name and yara_rule_description are all converted to lower case and _ are replaces with spaces

# %%
anomalies['anomaly_name'] = anomalies['anomaly_name'].replace('_', ' ', regex=True).str.lower()
anomalies
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     e900de5aea86567fadc7507a6811596eb4b86a14
# 2     12d263832d7f08122fbfc4431da22016e0823539
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 3233  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3234  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 3235  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 3236  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 3237  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 2     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 3233  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3234  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 3235  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 3236  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 3237  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5          anomaly_name
# 0     d6cda532ce834b973d5292e05e1d6c38  checksum header zero
# 1     e076afd88fe6a708d91a3f771754e860  checksum header zero
# 2     497d3c4d08b80e03f622064dced10135         entropy based
# 3     497d3c4d08b80e03f622064dced10135  checksum header zero
# 4     260bf0106c006d4e988a2685df71a758  checksum header zero
# ...                                ...                   ...
# 3233  c9f771be253b6ca1d7a808d7d65c5e29         entropy based
# 3234  c9f771be253b6ca1d7a808d7d65c5e29  checksum header zero
# 3235  0550342e66698384f232ac39b700dd14  checksum header zero
# 3236  fe783ff4bccd76cb215ee1f7738d9ed5  checksum header zero
# 3237  1b47215513edd622ba825dced07c8969  checksum header zero
#
# [3238 rows x 4 columns]

# %% [markdown]
# # Attacks

# %%
attacks = pd.read_csv(path_OTX_Attacks, low_memory = False)
attacks.head(3)
# Out:
#     attack_type                       attack_name attack_id  \
# 0  Installation  Registry Run Keys / Start Folder     T1060
# 1    Objectives                     Input Capture     T1056
# 2  Installation  Registry Run Keys / Start Folder     T1060
#
#                                        sha1  \
# 0  713a00b13a87c52b43404cd32d0f4645844709d9
# 1  713a00b13a87c52b43404cd32d0f4645844709d9
# 2  e900de5aea86567fadc7507a6811596eb4b86a14
#
#                                                              sha256  \
# 0  3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 1  3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2  3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
#
#                                 md5
# 0  97ad0714b0245825407dd25d7d168d31
# 1  97ad0714b0245825407dd25d7d168d31
# 2  e076afd88fe6a708d91a3f771754e860

# %%
attack_columns = ['sha1', 'sha256', 'md5', 'attack_id', 'attack_name', 'attack_type']
attacks = attacks[attack_columns]
attacks
# Out:
#                                           sha1  \
# 0     713a00b13a87c52b43404cd32d0f4645844709d9
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     12d263832d7f08122fbfc4431da22016e0823539
# ...                                        ...
# 5391  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 5392  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5393  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5394  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5395  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# ...                                                                ...
# 5391  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 5392  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5393  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5394  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5395  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5 attack_id  \
# 0     97ad0714b0245825407dd25d7d168d31     T1060
# 1     97ad0714b0245825407dd25d7d168d31     T1056
# 2     e076afd88fe6a708d91a3f771754e860     T1060
# 3     497d3c4d08b80e03f622064dced10135     T1119
# 4     497d3c4d08b80e03f622064dced10135     T1045
# ...                                ...       ...
# 5391  fe783ff4bccd76cb215ee1f7738d9ed5     T1055
# 5392  1b47215513edd622ba825dced07c8969     T1060
# 5393  1b47215513edd622ba825dced07c8969     T1045
# 5394  1b47215513edd622ba825dced07c8969     T1055
# 5395  1b47215513edd622ba825dced07c8969     T1056
#
#                                 attack_name   attack_type
# 0          Registry Run Keys / Start Folder  Installation
# 1                             Input Capture    Objectives
# 2          Registry Run Keys / Start Folder  Installation
# 3                      Automated Collection    Objectives
# 4                          Software Packing  Installation
# ...                                     ...           ...
# 5391  Defense Evasion, Privilege Escalation  Installation
# 5392       Registry Run Keys / Start Folder  Installation
# 5393                       Software Packing  Installation
# 5394  Defense Evasion, Privilege Escalation  Installation
# 5395                          Input Capture    Objectives
#
# [5396 rows x 6 columns]

# %% [markdown]
# #### Missing Values
#
# - drop rows with missing values related to sha1 sha256 and md5 field because they cannot be associate to any file

# %%
attacks.dropna(subset=['sha1', 'sha256', 'md5'], inplace=True)
attacks.reset_index(drop=True, inplace=True)

attacks
# Out:
#                                           sha1  \
# 0     713a00b13a87c52b43404cd32d0f4645844709d9
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     12d263832d7f08122fbfc4431da22016e0823539
# ...                                        ...
# 5391  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 5392  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5393  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5394  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 5395  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# ...                                                                ...
# 5391  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 5392  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5393  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5394  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 5395  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5 attack_id  \
# 0     97ad0714b0245825407dd25d7d168d31     T1060
# 1     97ad0714b0245825407dd25d7d168d31     T1056
# 2     e076afd88fe6a708d91a3f771754e860     T1060
# 3     497d3c4d08b80e03f622064dced10135     T1119
# 4     497d3c4d08b80e03f622064dced10135     T1045
# ...                                ...       ...
# 5391  fe783ff4bccd76cb215ee1f7738d9ed5     T1055
# 5392  1b47215513edd622ba825dced07c8969     T1060
# 5393  1b47215513edd622ba825dced07c8969     T1045
# 5394  1b47215513edd622ba825dced07c8969     T1055
# 5395  1b47215513edd622ba825dced07c8969     T1056
#
#                                 attack_name   attack_type
# 0          Registry Run Keys / Start Folder  Installation
# 1                             Input Capture    Objectives
# 2          Registry Run Keys / Start Folder  Installation
# 3                      Automated Collection    Objectives
# 4                          Software Packing  Installation
# ...                                     ...           ...
# 5391  Defense Evasion, Privilege Escalation  Installation
# 5392       Registry Run Keys / Start Folder  Installation
# 5393                       Software Packing  Installation
# 5394  Defense Evasion, Privilege Escalation  Installation
# 5395                          Input Capture    Objectives
#
# [5396 rows x 6 columns]

# %% [markdown]
# # Behaviours

# %%
actions = pd.read_csv(path_OTX_Behaviours, low_memory = False)
actions.head(3)
# Out:
#                                        sha1  \
# 0  b701b181de8e595225668cb65d5b975e5b300a39
# 1  b701b181de8e595225668cb65d5b975e5b300a39
# 2  b701b181de8e595225668cb65d5b975e5b300a39
#
#                                                              sha256  \
# 0  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
#
#                                 md5                     name  \
# 0  d6cda532ce834b973d5292e05e1d6c38          checks_debugger
# 1  d6cda532ce834b973d5292e05e1d6c38     generates_crypto_key
# 2  d6cda532ce834b973d5292e05e1d6c38  antivm_memory_available
#
#                                                                                                                  description  \
# 0                                                                          Checks if process is being debugged by a debugger
# 1                                                                          Uses Windows APIs to generate a cryptographic key
# 2  Checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
#
#    severity  markcount
# 0       1.0        2.0
# 1       1.0        3.0
# 2       1.0        1.0

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Column Renaming

# %%
actions.rename(columns=
               {   'name'        : 'action_name', 
                   'description' : 'action_description', 
                   'severity'    : 'action_severity', 
                   'markcount'   : 'action_counter'}, inplace=True)
actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks_debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates_crypto_key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm_memory_available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates_rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm_network_adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection_ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection_resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network_icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead_host
# 44966  1b47215513edd622ba825dced07c8969               injection_runpe
#
#                                                                                                                 action_description  \
# 0                                                                                Checks if process is being debugged by a debugger
# 1                                                                                Uses Windows APIs to generate a cryptographic key
# 2        Checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   Allocates read-write-execute memory (usually to unpack itself)
# 4                                                  Checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               Used NtSetContextThread to modify a thread in a remote process indicative of process injection
# 44963                                   Resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  Generates some ICMP traffic
# 44965  Connects to an IP address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       Executed a process and injected code into it, probably while unpacking
#
#        action_severity  action_counter
# 0                  1.0             2.0
# 1                  1.0             3.0
# 2                  1.0             1.0
# 3                  2.0            28.0
# 4                  2.0             1.0
# ...                ...             ...
# 44962              3.0             2.0
# 44963              3.0             2.0
# 44964              4.0             0.0
# 44965              5.0             1.0
# 44966              5.0            21.0
#
# [44967 rows x 7 columns]

# %%
completeness = 1 - actions['sha1'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'sha1': {completeness * 100:.2f}%")

completeness = 1 - actions['sha256'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'sha256': {completeness * 100:.2f}%")

completeness = 1 - actions['md5'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'md5': {completeness * 100:.2f}%")

completeness = 1 - actions['action_counter'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'action_counter': {completeness * 100:.2f}%")

completeness = 1 - actions['action_severity'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'action_severity': {completeness * 100:.2f}%")

completeness = 1 - actions['action_name'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'action_name': {completeness * 100:.2f}%")

completeness = 1 - actions['action_description'].isna().mean()

# Print the completeness percentage
print(f"Completeness for 'action_description': {completeness * 100:.2f}%")
# Out:
# Completeness for 'sha1': 100.00%
# Completeness for 'sha256': 100.00%
# Completeness for 'md5': 100.00%
# Completeness for 'action_counter': 84.35%
# Completeness for 'action_severity': 100.00%
# Completeness for 'action_name': 100.00%
# Completeness for 'action_description': 100.00%

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Data Type Conversion
#
# - action_counter field : from float to int

# %%
actions['action_counter'] = actions['action_counter'].astype('Int64')

# %% [markdown]
# - action_severity field : from float to int

# %%
actions['action_severity'] = actions['action_severity'].astype('Int64')

# %%
actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks_debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates_crypto_key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm_memory_available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates_rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm_network_adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection_ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection_resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network_icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead_host
# 44966  1b47215513edd622ba825dced07c8969               injection_runpe
#
#                                                                                                                 action_description  \
# 0                                                                                Checks if process is being debugged by a debugger
# 1                                                                                Uses Windows APIs to generate a cryptographic key
# 2        Checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   Allocates read-write-execute memory (usually to unpack itself)
# 4                                                  Checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               Used NtSetContextThread to modify a thread in a remote process indicative of process injection
# 44963                                   Resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  Generates some ICMP traffic
# 44965  Connects to an IP address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       Executed a process and injected code into it, probably while unpacking
#
#        action_severity  action_counter
# 0                    1               2
# 1                    1               3
# 2                    1               1
# 3                    2              28
# 4                    2               1
# ...                ...             ...
# 44962                3               2
# 44963                3               2
# 44964                4               0
# 44965                5               1
# 44966                5              21
#
# [44967 rows x 7 columns]

# %% [markdown]
# ## Error Correction
#
# #### Missing Values
#
# - drop rows with missing values related to sha1 sha256 and md5 field because they cannot be associate to any file
# - drop action counter due to missing and because not so interesting for organizations

# %%
actions.dropna(subset=['sha1', 'sha256', 'md5'], inplace=True)
actions = actions.drop(columns=['action_counter'])

actions.reset_index(drop=True, inplace=True)

actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks_debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates_crypto_key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm_memory_available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates_rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm_network_adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection_ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection_resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network_icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead_host
# 44966  1b47215513edd622ba825dced07c8969               injection_runpe
#
#                                                                                                                 action_description  \
# 0                                                                                Checks if process is being debugged by a debugger
# 1                                                                                Uses Windows APIs to generate a cryptographic key
# 2        Checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   Allocates read-write-execute memory (usually to unpack itself)
# 4                                                  Checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               Used NtSetContextThread to modify a thread in a remote process indicative of process injection
# 44963                                   Resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  Generates some ICMP traffic
# 44965  Connects to an IP address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       Executed a process and injected code into it, probably while unpacking
#
#        action_severity
# 0                    1
# 1                    1
# 2                    1
# 3                    2
# 4                    2
# ...                ...
# 44962                3
# 44963                3
# 44964                4
# 44965                5
# 44966                5
#
# [44967 rows x 6 columns]

# %% [markdown]
# #### Standardization
#
# The format of columns 'action_name' and 'action_description' is standardizaded: all to lower cases and _ replaced with spaces

# %%
actions['action_name'] = actions['action_name'].replace('_', ' ', regex=True).str.lower()
actions['action_description'] = actions['action_description'].str.lower()

actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates crypto key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm memory available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm network adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead host
# 44966  1b47215513edd622ba825dced07c8969               injection runpe
#
#                                                                                                                 action_description  \
# 0                                                                                checks if process is being debugged by a debugger
# 1                                                                                uses windows apis to generate a cryptographic key
# 2        checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   allocates read-write-execute memory (usually to unpack itself)
# 4                                                  checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               used ntsetcontextthread to modify a thread in a remote process indicative of process injection
# 44963                                   resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  generates some icmp traffic
# 44965  connects to an ip address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       executed a process and injected code into it, probably while unpacking
#
#        action_severity
# 0                    1
# 1                    1
# 2                    1
# 3                    2
# 4                    2
# ...                ...
# 44962                3
# 44963                3
# 44964                4
# 44965                5
# 44966                5
#
# [44967 rows x 6 columns]

# %% [markdown]
# ## Data Enrichment
# #### Prepare to data Integration
# Adding a field 'action_severity_level' by looking at the distribution we use a rule in order to determine malicious, sospicious and neutral actions with a rule.
# - 'action_severity' > 4 , set 'action_severity_level' to 'malicious'
# - 'action_severity' <= 2 , set 'action_severity_level' to 'neutral'
# - 'action_severity' > 2 and <= 4 , set 'action_severity_level' to 'suspicious'
#
# And drop action_severity column

# %%
actions.loc[(actions['action_severity'] > 4), 'action_level'] = 'malicious'
actions.loc[(actions['action_severity'] <= 4 ) & (actions['action_severity'] > 2 ), 'action_level'] = 'suspicious'
actions.loc[(actions['action_severity'] <= 2), 'action_level'] = 'neutral'

actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates crypto key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm memory available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm network adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead host
# 44966  1b47215513edd622ba825dced07c8969               injection runpe
#
#                                                                                                                 action_description  \
# 0                                                                                checks if process is being debugged by a debugger
# 1                                                                                uses windows apis to generate a cryptographic key
# 2        checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   allocates read-write-execute memory (usually to unpack itself)
# 4                                                  checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               used ntsetcontextthread to modify a thread in a remote process indicative of process injection
# 44963                                   resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  generates some icmp traffic
# 44965  connects to an ip address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       executed a process and injected code into it, probably while unpacking
#
#        action_severity action_level
# 0                    1      neutral
# 1                    1      neutral
# 2                    1      neutral
# 3                    2      neutral
# 4                    2      neutral
# ...                ...          ...
# 44962                3   suspicious
# 44963                3   suspicious
# 44964                4   suspicious
# 44965                5    malicious
# 44966                5    malicious
#
# [44967 rows x 7 columns]

# %%
actions = actions.drop(columns = ['action_severity'])
actions
# Out:
#                                            sha1  \
# 0      b701b181de8e595225668cb65d5b975e5b300a39
# 1      b701b181de8e595225668cb65d5b975e5b300a39
# 2      b701b181de8e595225668cb65d5b975e5b300a39
# 3      b701b181de8e595225668cb65d5b975e5b300a39
# 4      b701b181de8e595225668cb65d5b975e5b300a39
# ...                                         ...
# 44962  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44963  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44964  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44965  98837feaac2ed17b3709e5183b660dd41e7a1e0e
# 44966  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                  sha256  \
# 0      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 2      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 3      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 4      58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# ...                                                                 ...
# 44962  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44963  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44964  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44965  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
# 44966  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                     md5                   action_name  \
# 0      d6cda532ce834b973d5292e05e1d6c38               checks debugger
# 1      d6cda532ce834b973d5292e05e1d6c38          generates crypto key
# 2      d6cda532ce834b973d5292e05e1d6c38       antivm memory available
# 3      d6cda532ce834b973d5292e05e1d6c38                 allocates rwx
# 4      d6cda532ce834b973d5292e05e1d6c38       antivm network adapters
# ...                                 ...                           ...
# 44962  1b47215513edd622ba825dced07c8969  injection ntsetcontextthread
# 44963  1b47215513edd622ba825dced07c8969        injection resumethread
# 44964  1b47215513edd622ba825dced07c8969                  network icmp
# 44965  1b47215513edd622ba825dced07c8969                     dead host
# 44966  1b47215513edd622ba825dced07c8969               injection runpe
#
#                                                                                                                 action_description  \
# 0                                                                                checks if process is being debugged by a debugger
# 1                                                                                uses windows apis to generate a cryptographic key
# 2        checks amount of memory in system, this can be used to detect virtual machines that have a low amount of memory available
# 3                                                                   allocates read-write-execute memory (usually to unpack itself)
# 4                                                  checks adapter addresses which can be used to detect virtual network interfaces
# ...                                                                                                                            ...
# 44962                               used ntsetcontextthread to modify a thread in a remote process indicative of process injection
# 44963                                   resumed a suspended thread in a remote process potentially indicative of process injection
# 44964                                                                                                  generates some icmp traffic
# 44965  connects to an ip address that is no longer responding to requests (legitimate services will remain up-and-running usually)
# 44966                                                       executed a process and injected code into it, probably while unpacking
#
#       action_level
# 0          neutral
# 1          neutral
# 2          neutral
# 3          neutral
# 4          neutral
# ...            ...
# 44962   suspicious
# 44963   suspicious
# 44964   suspicious
# 44965    malicious
# 44966    malicious
#
# [44967 rows x 6 columns]

# %% [markdown]
# # Threat Vendor Analysis

# %%
tv_analysis = pd.read_csv(path_OTX_TV_Analysis, low_memory = False)
tv_analysis.head(3)
# Out:
#                                        sha1  \
# 0  b701b181de8e595225668cb65d5b975e5b300a39
# 1  713a00b13a87c52b43404cd32d0f4645844709d9
# 2  e900de5aea86567fadc7507a6811596eb4b86a14
#
#                                                              sha256  \
# 0  58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1  3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2  3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
#
#                                 md5                     malware  \
# 0  d6cda532ce834b973d5292e05e1d6c38       Win32:PWSX-gen\ [Trj]
# 1  97ad0714b0245825407dd25d7d168d31           Win32:Malware-gen
# 2  e076afd88fe6a708d91a3f771754e860  Win32:BackdoorX-gen\ [Trj]
#
#                  verdict threat_vendor_name
# 0  ['Malware infection']              avast
# 1  ['Malware infection']              avast
# 2  ['Malware infection']              avast

# %% [markdown]
# ## Data Manipuliation

# %% [markdown]
# - verdict field : from list of strings to string

# %%
import re

# %%
tv_analysis['verdict'].unique()
# Out:
# array(["['Malware infection']", nan, "['Malware detected']"], dtype=object)

# %%
def replace_value(x):
    # Use a regular expression to extract the value between square brackets
    if( pd.isna(x) ):
        return x
    match = re.search(r"\['(.*?)'\]", x)
    if match:
        original_value = match.group(1)
        # Replace the original value with the new value
        return original_value
    else:
        return x 

def cleaning_tv_analysis(df):
    
    df['verdict'] = df['verdict'].apply(lambda x: replace_value(x))
        
    return df

# %%
tv_analysis = cleaning_tv_analysis(tv_analysis)
tv_analysis
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 7969  3ab53037e2360c42b57d213234ced58717844a71
# 7970  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 7971  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 7972  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 7973  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 7969  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 7970  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 7971  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 7972  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 7973  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5                        malware  \
# 0     d6cda532ce834b973d5292e05e1d6c38          Win32:PWSX-gen\ [Trj]
# 1     97ad0714b0245825407dd25d7d168d31              Win32:Malware-gen
# 2     e076afd88fe6a708d91a3f771754e860     Win32:BackdoorX-gen\ [Trj]
# 3     497d3c4d08b80e03f622064dced10135         MSIL:NanoCore-B\ [Trj]
# 4     260bf0106c006d4e988a2685df71a758       Win32:RemcosRAT-A\ [Trj]
# ...                                ...                            ...
# 7969  e0fea510c784eb0e440e99e53d83d414  Win.Malware.Generic-6623004-0
# 7970  c9f771be253b6ca1d7a808d7d65c5e29     Win.Malware.Dlmc-7395626-0
# 7971  0550342e66698384f232ac39b700dd14     Win.Packed.Samas-7998113-0
# 7972  fe783ff4bccd76cb215ee1f7738d9ed5                            NaN
# 7973  1b47215513edd622ba825dced07c8969                            NaN
#
#                 verdict threat_vendor_name
# 0     Malware infection              avast
# 1     Malware infection              avast
# 2     Malware infection              avast
# 3     Malware infection              avast
# 4     Malware infection              avast
# ...                 ...                ...
# 7969  Malware infection             clamav
# 7970  Malware infection             clamav
# 7971  Malware infection             clamav
# 7972                NaN             clamav
# 7973                NaN             clamav
#
# [7974 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Standardization
# Replace malware and verdict with a lower case format

# %%
tv_analysis['malware'] = tv_analysis['malware'].str.lower()
tv_analysis['verdict'] = tv_analysis['verdict'].str.lower()

tv_analysis
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 7969  3ab53037e2360c42b57d213234ced58717844a71
# 7970  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 7971  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 7972  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 7973  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 7969  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 7970  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 7971  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 7972  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 7973  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5                        malware  \
# 0     d6cda532ce834b973d5292e05e1d6c38          win32:pwsx-gen\ [trj]
# 1     97ad0714b0245825407dd25d7d168d31              win32:malware-gen
# 2     e076afd88fe6a708d91a3f771754e860     win32:backdoorx-gen\ [trj]
# 3     497d3c4d08b80e03f622064dced10135         msil:nanocore-b\ [trj]
# 4     260bf0106c006d4e988a2685df71a758       win32:remcosrat-a\ [trj]
# ...                                ...                            ...
# 7969  e0fea510c784eb0e440e99e53d83d414  win.malware.generic-6623004-0
# 7970  c9f771be253b6ca1d7a808d7d65c5e29     win.malware.dlmc-7395626-0
# 7971  0550342e66698384f232ac39b700dd14     win.packed.samas-7998113-0
# 7972  fe783ff4bccd76cb215ee1f7738d9ed5                            NaN
# 7973  1b47215513edd622ba825dced07c8969                            NaN
#
#                 verdict threat_vendor_name
# 0     malware infection              avast
# 1     malware infection              avast
# 2     malware infection              avast
# 3     malware infection              avast
# 4     malware infection              avast
# ...                 ...                ...
# 7969  malware infection             clamav
# 7970  malware infection             clamav
# 7971  malware infection             clamav
# 7972                NaN             clamav
# 7973                NaN             clamav
#
# [7974 rows x 6 columns]

# %% [markdown]
# #### Missing Values
#
# - drop rows with missing values related to sha1 sha256 and md5 field because they cannot be associate to any file

# %%
tv_analysis.dropna(subset=['sha1', 'sha256', 'md5'], inplace=True)
tv_analysis
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 7969  3ab53037e2360c42b57d213234ced58717844a71
# 7970  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 7971  ba5e50a39d1502e38196724ec9d844ee4bf8d002
# 7972  d14540087dd6d350fb49e644e53ccefc0e4c1582
# 7973  98837feaac2ed17b3709e5183b660dd41e7a1e0e
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 7969  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 7970  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 7971  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
# 7972  dba8a4717d516772b8cc06bd258265f21f7db6ddab62328917524c5a243c67a1
# 7973  5b37ddd18800dc91071db31b340e8f9997bb89d42d5a194d7ff8c980a54abe89
#
#                                    md5                        malware  \
# 0     d6cda532ce834b973d5292e05e1d6c38          win32:pwsx-gen\ [trj]
# 1     97ad0714b0245825407dd25d7d168d31              win32:malware-gen
# 2     e076afd88fe6a708d91a3f771754e860     win32:backdoorx-gen\ [trj]
# 3     497d3c4d08b80e03f622064dced10135         msil:nanocore-b\ [trj]
# 4     260bf0106c006d4e988a2685df71a758       win32:remcosrat-a\ [trj]
# ...                                ...                            ...
# 7969  e0fea510c784eb0e440e99e53d83d414  win.malware.generic-6623004-0
# 7970  c9f771be253b6ca1d7a808d7d65c5e29     win.malware.dlmc-7395626-0
# 7971  0550342e66698384f232ac39b700dd14     win.packed.samas-7998113-0
# 7972  fe783ff4bccd76cb215ee1f7738d9ed5                            NaN
# 7973  1b47215513edd622ba825dced07c8969                            NaN
#
#                 verdict threat_vendor_name
# 0     malware infection              avast
# 1     malware infection              avast
# 2     malware infection              avast
# 3     malware infection              avast
# 4     malware infection              avast
# ...                 ...                ...
# 7969  malware infection             clamav
# 7970  malware infection             clamav
# 7971  malware infection             clamav
# 7972                NaN             clamav
# 7973                NaN             clamav
#
# [7938 rows x 6 columns]

# %% [markdown]
# - drop row if both the fields 'verdict' and 'malware' are missing because any information can be taken from that row, so it will be useless

# %%
tv_analysis.dropna(subset=['malware', 'verdict'], how='all', inplace=True)
tv_analysis.reset_index(drop=True, inplace=True)
tv_analysis
# Out:
#                                           sha1  \
# 0     b701b181de8e595225668cb65d5b975e5b300a39
# 1     713a00b13a87c52b43404cd32d0f4645844709d9
# 2     e900de5aea86567fadc7507a6811596eb4b86a14
# 3     12d263832d7f08122fbfc4431da22016e0823539
# 4     18a703514e47e1c3b59cf12de95f1ea5c7475083
# ...                                        ...
# 4463  0d7b506cdc8e0228a8c50f1adf3b1b3224fc114d
# 4464  a3447ba9b83f30284c6d3effb45c31ad9d5f258f
# 4465  3ab53037e2360c42b57d213234ced58717844a71
# 4466  4f9b9859a596a8bfdfee516788587ca0c0fb6ae8
# 4467  ba5e50a39d1502e38196724ec9d844ee4bf8d002
#
#                                                                 sha256  \
# 0     58edde581177c6f96caa4da4cd73396afee160b9152692a664b28aa67dd0d100
# 1     3b96a384f9989f28315eb374eae991e70ed07b88665cbf831f24bd574502feac
# 2     3363270a2950c8518e7883ea147b3f947b3a96aa31d37a990c73f975946335ce
# 3     cf1260b1d0686dbee4a5c9e3bcd09eff07bfae0a53d17356b72150f59ad1a497
# 4     28b6bbc6b1d6ee21ccdc25c5eefccad5e21556954542cd19a0a87f7dde91df78
# ...                                                                ...
# 4463  a48ab00c2a748d146264d9ceebed2346013a730bde2ee91bc03de76f8d262aa1
# 4464  bbd3ecd9e9671d94e8897980c4eb9391ae9cb444615ed9a93b8221ae8fa66790
# 4465  5de4932cb0ccab3fec711135cdd1af5a09c26a870bfb2d2adc650d0fdbf16488
# 4466  f10dd5ce32d72489dd2696e5b58ee115f3cd065969a61a6613cab27bcd57de70
# 4467  f3fcbb0fedb1e3b732185aebbf845ca185c950ca3635026d8a754312220577c9
#
#                                    md5                          malware  \
# 0     d6cda532ce834b973d5292e05e1d6c38            win32:pwsx-gen\ [trj]
# 1     97ad0714b0245825407dd25d7d168d31                win32:malware-gen
# 2     e076afd88fe6a708d91a3f771754e860       win32:backdoorx-gen\ [trj]
# 3     497d3c4d08b80e03f622064dced10135           msil:nanocore-b\ [trj]
# 4     260bf0106c006d4e988a2685df71a758         win32:remcosrat-a\ [trj]
# ...                                ...                              ...
# 4463  1e53278bd1d1ee7c84ffc2d44dce4117        win.packed.zusy-6860439-0
# 4464  f6eec1317ece3ffb7c4916e224d9734d  win.trojan.revengerat-6344273-0
# 4465  e0fea510c784eb0e440e99e53d83d414    win.malware.generic-6623004-0
# 4466  c9f771be253b6ca1d7a808d7d65c5e29       win.malware.dlmc-7395626-0
# 4467  0550342e66698384f232ac39b700dd14       win.packed.samas-7998113-0
#
#                 verdict threat_vendor_name
# 0     malware infection              avast
# 1     malware infection              avast
# 2     malware infection              avast
# 3     malware infection              avast
# 4     malware infection              avast
# ...                 ...                ...
# 4463  malware infection             clamav
# 4464  malware infection             clamav
# 4465  malware infection             clamav
# 4466  malware infection             clamav
# 4467  malware infection             clamav
#
# [4468 rows x 6 columns]

# %% [markdown]
# ## Saving

# %%
dataframes_dict = {}

# Add the DataFrames to the dictionary with keys
dataframes_dict['Entries'] = entries
dataframes_dict['TV_Analysis'] = tv_analysis
dataframes_dict['Behaviours'] = actions
dataframes_dict['Anomalies'] = anomalies
dataframes_dict['Attacks'] = attacks

# %%
save_directory = "C:\\Users\\leona\\OneDrive\\Desktop\\Tesi\\Pipeline\\Datasets\\Pipeline\\FileAnalysis\\PostDataCleaning\\OTX_Alien_Vault\\"
for key, df in dataframes_dict.items():
    file_name = f"{key}.csv"
    file_path = save_directory + file_name
    df.to_csv(file_path, index=False)
    print(f'{key} added')
# Out:
# Entries added
# TV_Analysis added
# Behaviours added
# Anomalies added
# Attacks added
